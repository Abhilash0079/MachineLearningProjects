# %% [markdown]
# ## Sample Data Understanding

# %%
import pandas as pd
import sys
from pathlib import Path

# %%
# Add project root to path
project_root = Path.cwd().parent

if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
from src.data.load_data import (
    load_sample_train_data
)

# %%
df = load_sample_train_data(
    n_rows=5000
)

df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
df.shape
# Out:
# (5000, 23)

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'trans_date_trans_time',
#  'cc_num',
#  'merchant',
#  'category',
#  'amt',
#  'first',
#  'last',
#  'gender',
#  'street',
#  'city',
#  'state',
#  'zip',
#  'lat',
#  'long',
#  'city_pop',
#  'job',
#  'dob',
#  'trans_num',
#  'unix_time',
#  'merch_lat',
#  'merch_long',
#  'is_fraud']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5000 non-null   int64
#  1   trans_date_trans_time  5000 non-null   str
#  2   cc_num                 5000 non-null   int64
#  3   merchant               5000 non-null   str
#  4   category               5000 non-null   str
#  5   amt                    5000 non-null   float64
#  6   first                  5000 non-null   str
#  7   last                   5000 non-null   str
#  8   gender                 5000 non-null   str
#  9   street                 5000 non-null   str
#  10  city                   5000 non-null   str
#  11  state                  5000 non-null   str
#  12  zip                    5000 non-null   int64
#  13  lat                    5000 non-null   float64
#  14  long                   5000 non-null   float64
# ...

# %%
memory_usage = (
    df.memory_usage(deep=True)
      .sum()
      / 1024**2
)

print(
    f"Memory Usage: {memory_usage:.2f} MB"
)
# Out:
# Memory Usage: 1.64 MB

# %%
missing_values = (
    df.isnull()
      .sum()
      .sort_values(
          ascending=False
      )
)

missing_values[
    missing_values > 0
]
# Out:
# Series([], dtype: int64)

# %%
duplicate_count = (
    df.duplicated()
      .sum()
)

print(
    f"Duplicate Rows: {duplicate_count}"
)
# Out:
# Duplicate Rows: 0

# %%
df["is_fraud"].value_counts()
# Out:
# is_fraud
# 0    4978
# 1      22
# Name: count, dtype: int64

# %%
summary = pd.DataFrame({
    "Column": df.columns,
    "DataType": df.dtypes.values,
    "Missing Values": df.isnull().sum().values,
    "Unique Values": [
        df[col].nunique()
        for col in df.columns
    ]
})

summary
# Out:
#                    Column DataType  Missing Values  Unique Values
# 0              Unnamed: 0    int64               0           5000
# 1   trans_date_trans_time      str               0           4936
# 2                  cc_num    int64               0            876
# 3                merchant      str               0            692
# 4                category      str               0             14
# 5                     amt  float64               0           3906
# 6                   first      str               0            327
# 7                    last      str               0            452
# 8                  gender      str               0              2
# 9                  street      str               0            876
# 10                   city      str               0            811
# 11                  state      str               0             50
# 12                    zip    int64               0            866
# ...

# %% [markdown]
# ### <b>Feature Classification</b>
#
# #### <b>Customer Features</b>
# - cc_num
# - gender
# - dob
# - job
# - city_pop
#
# #### <b>Transaction Features</b>
# - trans_date_trans_time
# - merchant
# - category
# - amt
#
# #### <b>Location Features</b>
# - city
# - state
# - lat
# - long
# - merch_lat
# - merch_long
#
# #### <b>Target Variable</b>
# - is_fraud

# %% [markdown]
# ## Full Data Understanding

# %%
from src.data.load_data import load_full_train_data

df_full = load_full_train_data()

# %%
df_full.shape
# Out:
# (1296675, 23)

# %%
df_full.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
(df_full["is_fraud"].value_counts(normalize=True) *100).round(3)
# Out:
# is_fraud
# 0    99.421
# 1     0.579
# Name: proportion, dtype: float64

# %%
print(df_full.duplicated().sum())
# Out:
# 0
